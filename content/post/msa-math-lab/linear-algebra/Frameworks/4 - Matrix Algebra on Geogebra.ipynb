# %% [markdown]
# ## Geogebra & Frameworks

# %% [markdown]
# **Geogebra.** Verify final answers computed in _On-Paper_ section.

# %% [markdown]
# ---
# ## Scratch

# %%
l = [1, 60, 4, 100]

# %%
max(l)
# Out:
# 100
