# %% [markdown]
# ### Question

# %% [markdown]
# Evaluate the second order derivative of
#
# $$
# f(x) = x^3
# $$

# %% [markdown]
# #### Solution

# %% [markdown]
# \begin{align}
# f'(x) &= 3x^2 \\
# f''(x) &= 6x
# \end{align}
