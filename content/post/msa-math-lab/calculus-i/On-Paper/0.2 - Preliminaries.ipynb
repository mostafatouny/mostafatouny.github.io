# %% [markdown]
# ## High-School Pre-Algebra

# %% [markdown]
# - Multiplication, Addition, Subtration.
# - Multiplicative inverse, Additive inverse.
# - Factorization.
# - Solving a quadratic equation.

# %% [markdown]
# ### Factorization

# %% [markdown]
# **Question.** Factorize the following algebraic form:
# \begin{align}
# a^2 - b^2
# \end{align}

# %% [markdown]
# \begin{align}
# a^2 - b^2 = a^2 - ab + ab - b^2 = a(a-b) + b(a-b) = (a+b)(a-b)
# \end{align}

# %% [markdown]
# ### Resources

# %% [markdown]
# **[Khan Academy - Pre-algebra](https://www.khanacademy.org/math/pre-algebra)**

# %% [markdown]
# ![prealg.png](data:image/png;base64,...)

# %% [markdown]
# **[Openstax - Pre-algebra](https://openstax.org/details/books/prealgebra-2e)**

# %% [markdown]
# ![prealg.png](data:image/png;base64,...)

# %% [markdown]
# ## High-School Trigonometry

# %% [markdown]
# - Trigonometric Functions for Limits, derivatives, integrals, ..etc.

# %% [markdown]
# ### Tangent

# %% [markdown]
# **Question.** Sketch the tangent function $tan(x)$.

# %% [markdown]
# **Answer.**

# %% [markdown]
# ![geogebra-export.png](data:image/png;base64,...)

# %% [markdown]
# ### Resources

# %% [markdown]
# **[Khan Academy - Trigonometry](https://www.khanacademy.org/math/trigonometry)**

# %% [markdown]
# ![trig.png](data:image/png;base64,...)

# %% [markdown]
# **[Openstax - Algebra and Trigonometry](https://openstax.org/details/books/algebra-and-trigonometry-2e)**

# %% [markdown]
# ![trig.png](data:image/png;base64,...)
