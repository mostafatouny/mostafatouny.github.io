# %% [markdown]
# ### Recap

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %% [markdown]
# `displayTree` recursively prints the nodes of a connected component.

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %% [markdown]
# output of `displayTree(0)`
# ```
# 0
# 1
# 2
# 3
# 4
# ```

# %% [markdown]
# ### Question 1

# %% [markdown]
# Use `displayTree` and `print` to print each nodes components, separated by `###`.

# %% [markdown]
# ![q3.png](data:image/png;base64,...)

# %% [markdown]
# Answer
# ```
#
# ```

# %% [markdown]
# ### Question 2

# %% [markdown]
# Use `displayTree` and `print` to print each nodes component, separated by `###`.

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %% [markdown]
# ### Question 3

# %% [markdown]
# Consider an array `visited` where `visited[i] = 1` means node `i` is visited and printed and `visited[i] = 0` means node `i` is not. Now use `displayTree(k, visited)` that takes `visited` array as an input and modifies it while printing the nodes.

# %% [markdown]
# Repeat _Question 2_ but with `displayTree(k, visited)`. Your program starts with
# ```
# visited = [0, 0, 0, 0, 0, 0, 0, 0]
# ```

# %% [markdown]
# ### Question 4

# %% [markdown]
# On the same input of _Question 2_, State whether the below program is True or False and justify.
#
# C++
# ```c++
# int visited[8];
# for (int i = 0 ; i< 8; i++) {
#     cout << "###";
#     displayTree(i, visited);
# }
#
# ```
# Python
# ```py
# visited = [0, 0, 0, 0, 0, 0, 0, 0]
# for i in range(8):
#   print("###")
#   displayTree(i, visited)
# ```

# %% [markdown]
# ### Question 5

# %% [markdown]
# Fix the program of _Question 4_ so that it prints the correct expected output given the input of _Question 2_, by adding a single conditional statement.
#
# C++
# ```c++
# int visited[8];
# for (int i = 0 ; i< 8; i++) {
#     if ( <condition here> ) {
#       cout << "###";
#       displayTree(i, visited);
#     }
# }
# ```
# Python
# ```py
# visited = [0, 0, 0, 0, 0, 0, 0, 0]
# for i in range(8):
#   if <condition here>:
#     print("###")
#     displayTree(i, visited)
# ```

# %% [markdown]
# ### Question 6 (Main Project)

# %% [markdown]
# Implement and test the code on the given input of _Question 2_, and the given input in _Project_.
