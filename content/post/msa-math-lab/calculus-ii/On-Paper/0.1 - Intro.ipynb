# %% [markdown]
# ## Motivation

# %% [markdown]
# [Stack Exchange](https://cs.stackexchange.com/questions/55462/how-when-is-calculus-used-in-computer-science/)

# %% [markdown]
# ![cal.png](data:image/png;base64,...)

# %% [markdown]
# ## Overview

# %% [markdown]
# [Wikipedia](https://en.wikipedia.org/wiki/Calculus)

# %% [markdown]
# ![cal.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## Design Thinking

# %% [markdown]
# [Problem-Solving and Mathematical Discovery by Waterloo](https://courseware.cemc.uwaterloo.ca/40)

# %% [markdown]
# ![Screenshot_2024-02-08_10-39-30.png](data:image/png;base64,...)

# %% [markdown]
# **Usage**
# - Studying the course content.
#   - You learn only when you think about it, Not when you sit in an arm-chair listening.

# %% [markdown]
# ## Scientific Methodologies

# %% [markdown]
# ### Logic

# %% [markdown]
# [Wikipedia](https://en.wikipedia.org/wiki/Logic)

# %% [markdown]
# ![tem.png](data:image/png;base64,...)

# %% [markdown]
# **Usage**
# - Solving lecture problems by studied theorems (rules).
# - Reading the Kolman's book formal definitions.

# %% [markdown]
# ### Science

# %% [markdown]
# [Wikipedia](https://en.wikipedia.org/wiki/Scientific_method)

# %% [markdown]
# ![linalg.png](data:image/png;base64,...)

# %% [markdown]
# **Usage**
# - Formulating real-life use-cases.
# - Experimentation on data.

# %% [markdown]
# ### Engineering

# %% [markdown]
# - [Better code, Toptal](https://www.toptal.com/software/six-commandments-of-good-code)
# - [Engineering Process, Teach Engineering](https://www.teachengineering.org/populartopics/designprocess)

# %% [markdown]
# ![Screenshot_2024-02-06_12-18-46.png](data:image/png;base64,...)

# %% [markdown]
# **Usage**
# - Course Project
#   - Testing.
#   - Single Responsibility.
#   - Readability.
