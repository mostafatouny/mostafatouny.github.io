# %% [markdown]
# # Lab Goals
# - Personal Introduction
# - Logistics
# - Motivation

# %% [markdown]
# ---

# %% [markdown]
# # 1.1 Personal Introduction

# %% [markdown]
# **Task 1.1** Tell us your name, your favorite field, next step, and big ambition.

# %% [markdown]
# # 2 Logistics

# %% [markdown]
# **Task 2.1** The lab accommodates _Tasks_, _Challenges_, and _Project_. Why are the three components necessary? In other words, Why don't we just practice on a project, or answer questions from the book's content?

# %% [markdown]
# **Task 2.2** Documenting and sharing your learning journey is timely consuming. Do you think the time invested is worthwhile, in case you benefited from your colleagues documentation? Why?

# %% [markdown]
# **Task 2.3** What kind of personal assistance you needed, and did not found in courses, as they had to follow a strict curriculum. If you were an instructor, How would you manage that?

# %% [markdown]
# **Task 2.4** Create a discord account, using either your MSA's email or personal email, if you don't one already.

# %% [markdown]
# # 3 Motivation

# %% [markdown]
# **Task 3.1** Search for job requirements on Linkedin or Wuzzuf. Is this course useful in anyway (You don't have to answer yes)?

# %% [markdown]
# **Task 3.2** Set-out a plan for how this course is going to align with your personal career path.

# %% [markdown]
# **Task 3.3** Create a linkedin account if you don't have already. Think of a good description to put on your resume.
