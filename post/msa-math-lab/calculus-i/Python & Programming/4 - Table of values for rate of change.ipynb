# %% [markdown]
# ## Python & Programming

# %% [markdown]
# **Table of values for the rate of change**

# %%
x = np.arange(0.0, 5.0, 1.0)
y = 2 * x

# %%
x
# Out:
# array([0., 1., 2., 3., 4.])

# %%
y
# Out:
# array([0., 2., 4., 6., 8.])

# %%
def rateOfChange( x1, y1, x2, y2 ):
  return (y2 - y1) / (x2 - x1)

def tableOfValues(x, y):
  n = len(x)
  for i in range(n-1):
    print( (y[n-1] - y[i]) / (x[n-1] - x[i]) )

# %%
tableOfValues(x,y)
# Out:
# 2.0
# 2.0
# 2.0
# 2.0
