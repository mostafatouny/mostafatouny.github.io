# %%
l = [1, 7, 9]

# %%
l[0]
# Out:
# 1

# %%
l[2]
# Out:
# 9

# %%
len(l)
# Out:
# 3

# %%
M = [
    [1, 5, 9],
    [8, 6, 1]
]
# list of lists

# %%
len(M)
# Out:
# 2

# %%
M[0]
# Out:
# [1, 5, 9]

# %%
M[1]
# Out:
# [8, 6, 1]

# %%
# second element of the first list
M[0][1]
# Out:
# 5

# %%
# third element of the second list
M[1][2]
# Out:
# 1

# %% [markdown]
# ---
# ## scratch

# %%
import numpy as np

# %%
arr = np.array([1, 6, 9])
arr
# Out:
# array([1, 6, 9])

# %%
arr + 1
# Out:
# array([ 2,  7, 10])

# %%
np.sum(arr)
# Out:
# 16

# %%
np.mean(arr)
# Out:
# 5.333333333333333

# %%
l = [1, 5 ,7]

# %%
type(l)
# Out:
# list

# %%
type(np.array(l))
# Out:
# numpy.ndarray

# %%
type(5.5)
# Out:
# float

# %%
type(int(5.5))
# Out:
# int
