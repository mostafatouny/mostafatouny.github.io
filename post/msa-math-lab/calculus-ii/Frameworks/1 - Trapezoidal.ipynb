# %% [markdown]
# **Geogebra**

# %% [markdown]
# Riemann Sums by Adrian Jannetta (in google drive)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# **Numpy, Trapezoidal** ([Source](https://numpy.org/doc/stable/reference/generated/numpy.trapz.html))

# %%
# a sequence of 50 numbers on [0 ~ 1]
x = np.linspace(0, 1, num=50)
x
# Out:
# array([0.        , 0.02040816, 0.04081633, 0.06122449, 0.08163265,
#        0.10204082, 0.12244898, 0.14285714, 0.16326531, 0.18367347,
#        0.20408163, 0.2244898 , 0.24489796, 0.26530612, 0.28571429,
#        0.30612245, 0.32653061, 0.34693878, 0.36734694, 0.3877551 ,
#        0.40816327, 0.42857143, 0.44897959, 0.46938776, 0.48979592,
#        0.51020408, 0.53061224, 0.55102041, 0.57142857, 0.59183673,
#        0.6122449 , 0.63265306, 0.65306122, 0.67346939, 0.69387755,
#        0.71428571, 0.73469388, 0.75510204, 0.7755102 , 0.79591837,
#        0.81632653, 0.83673469, 0.85714286, 0.87755102, 0.89795918,
#        0.91836735, 0.93877551, 0.95918367, 0.97959184, 1.        ])

# %%
# function computed on the sequence
y = f(x)
y
# Out:
# array([1.        , 0.99958351, 0.99833403, 0.99625156, 0.99333611,
#        0.98958767, 0.98500625, 0.97959184, 0.97334444, 0.96626406,
#        0.95835069, 0.94960433, 0.94002499, 0.92961266, 0.91836735,
#        0.90628905, 0.89337776, 0.87963349, 0.86505623, 0.84964598,
#        0.83340275, 0.81632653, 0.79841733, 0.77967514, 0.76009996,
#        0.7396918 , 0.71845065, 0.69637651, 0.67346939, 0.64972928,
#        0.62515618, 0.5997501 , 0.57351104, 0.54643898, 0.51853394,
#        0.48979592, 0.46022491, 0.42982091, 0.39858392, 0.36651395,
#        0.333611  , 0.29987505, 0.26530612, 0.22990421, 0.1936693 ,
#        0.15660142, 0.11870054, 0.07996668, 0.04039983, 0.        ])

# %%
# approximate the integral using trapezoidal
np.trapz(y, x)
# Out:
# 0.6665972511453562
