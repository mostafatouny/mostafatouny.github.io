# %% [markdown]
# **Geogebra.** Command `Determinant({{1, 2, 3}, {2, 1, 3}, {3, 1, 2}})` yielding 6

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Compute Determinant**

# %%
# kolman, p. 409
M = np.array([
    [1,2,3],
    [2,1,3],
    [3,1,2]
])

np.linalg.det(M)
# numeric error
# Out:
# 6.000000000000001
