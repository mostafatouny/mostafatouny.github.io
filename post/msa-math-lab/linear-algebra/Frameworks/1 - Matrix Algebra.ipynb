# %% [markdown]
# **Geogebra.** File in drive.

# %%
import numpy as np

# %% [markdown]
# **Matrix Algebra**

# %%
M
# Out:
# [[1, 2], [3, 4]]

# %%
N = np.array(M)

# %%
N
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# N^2 matrix
np.dot(N, N)
# Out:
# array([[ 7, 10],
#        [15, 22]])

# %%
# scalar multiplication
2 * N
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
# subtraction
N - N
# Out:
# array([[0, 0],
#        [0, 0]])

# %%
# vector [3, 3]
v = np.array([3, 3])

# matrix vector multiplication
np.dot(N, v)
# Out:
# array([ 9, 21])
