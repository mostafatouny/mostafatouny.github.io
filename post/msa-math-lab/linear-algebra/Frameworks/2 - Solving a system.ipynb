# %% [markdown]
# Solve the system of equations $x_0 + 2 x_1 = 1$ and $3 x_0 + 5 x_1 = 2$ ([source](https://numpy.org/doc/stable/reference/generated/numpy.linalg.solve.html#numpy.linalg.solve))

# %%
M = np.array([
  [1, 2],
  [3, 5]
])

b = np.array([1, 2])

# %%
x = np.linalg.solve(M, b)
x
# Out:
# array([-1.,  1.])
