# %% [markdown]
# **List Comprehension**

# %%
[ i for i in range(5) ]
# Out:
# [0, 1, 2, 3, 4]

# %%
[ i % 2 for i in range(5) ]
# Out:
# [0, 1, 0, 1, 0]

# %%
[ bool(i % 2) for i in range(5) ]
# Out:
# [False, True, False, True, False]

# %%
[ True if i % 2 == 0 else False for i in range(5) ]
# Out:
# [True, False, True, False, True]

# %%
[ "Sandra" if i % 2 == 0 else "Susanna" for i in range(5) ]
# Out:
# ['Sandra', 'Susanna', 'Sandra', 'Susanna', 'Sandra']
